# %%
import sys
import os

project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

from src.data_loader import load_data
from src.preprocessing import preprocess
from src.analysis import monthly_spend_analysis, category_spend_analysis
from src.visualization import plot_monthly_spend, plot_category_spend

transactions, customers = load_data()
transactions = preprocess(transactions)

monthly_spend = monthly_spend_analysis(transactions)
category_spend = category_spend_analysis(transactions)

plot_monthly_spend(monthly_spend)
plot_category_spend(category_spend)
# Out:
# Matplotlib is building the font cache; this may take a moment.
